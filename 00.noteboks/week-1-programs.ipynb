# %%
string = "123(hello)89A1D"
# output = "helloAD"

# %%
# 1st approach
result = ""
for i in string:
  if i.isalpha():
    result = result + i

print(result)
# Out:
# helloAD

# %%
# 2nd approach
result = []
for i in string:
  if i.isalpha():
    result.append(i)

print(''.join(result))
# Out:
# helloAD

# %%
num = 15
if num % 2 == 0:
  print(f'{num} even numer')
else:
  print(f'{num} odd numer')
# Out:
# 15 odd numer

# %%
string
# Out:
# '123(hello)89A1D'

# %%
# output = 123891
for char in string:
  if char.isnumeric():
    print(char, end='')
# Out:
# 123891

# %%
4%2
# Out:
# 0

# %%
num = 8
for i in range(2, num):
  if num % i == 0:
    print('not a prime')
    break
else:
  print("it is a prime")
# Out:
# not a prime
