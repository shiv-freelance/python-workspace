# %%
# abstraction:
#       is the behaviour of hiding the implementation (will not expose)

# %% [markdown]
# 1. inheritance -- super class, sub class
# 2. encapsulation -- wrapping data members (setter/getter) - providing security
# 3. polymorphism -- overloading, overriding
# 4. abstraction -- hiding implementation.

# %%
# abstract method, abstract class

class Test:
  def m1():
    pass

# %%
t = Test()

# %%
class SubTest(Test):
  pass

# %%
sub = SubTest()

# %%
from abc import ABC

class Test(ABC):

  def normal_test(self):
    pass

  def abstract_m1(self):
    pass

# %%
t = Test()

# %%
t.abstract_m1()

# %%
t.normal_test()

# %%
# abstract method --> unfinished, inprogress, ongoing (not completley done)

# %%
# abstract method creation
from abc import ABC, abstractmethod

class Test(ABC):

  def normal_test(self):
    pass

  @abstractmethod
  def abstract_m1(self):
    pass

# %%
t = Test() # in a class if you have a abstractmethod you can't create an object
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-fecbf383c762> in <cell line: 1>()
# ----> 1 t = Test() # in a class if you have a abstractmethod you can't create an object
#
# TypeError: Can't instantiate abstract class Test with abstract method abstract_m1

# %%
from abc import ABC # abstract base class

class A(ABC):
  def __init__(self):
    print('a class constructor')

  def test_a(self):
    print('test a method')

# %%
a = A() # if a class doesn't have any abstractmethods you can create an object.
# Out:
# a class constructor

# %%
from abc import ABC # abstract base class

class A(ABC):
  def __init__(self):
    print('a class constructor')
  @abstractmethod
  def test_a(self):
    print('test a method')

# %%
a = A()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-7f181d8f00b8> in <cell line: 1>()
# ----> 1 a = A()
#
# TypeError: Can't instantiate abstract class A with abstract method test_a

# %%
from abc import ABC, abstractmethod

class A: # if you don't inherit ABC class, you will loose abstract behaviour
  @abstractmethod
  def a_test(self):
    pass

# %%
a = A()

# %%
from abc import ABC, abstractmethod

class A(ABC): # if you don't inherit ABC class, you will loose abstract behaviour
  @abstractmethod
  def a_test(self):
    pass

# %%
a = A()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-7f181d8f00b8> in <cell line: 1>()
# ----> 1 a = A()
#
# TypeError: Can't instantiate abstract class A with abstract method a_test

# %%
from abc import ABC, abstractmethod

class A(ABC): # once you inherit ABC class, A class became abstract class (you can't do object intialization)
  @abstractmethod
  def a_test(self):
    pass

class B(A): # A class inherited, you will also become Abstract class
  pass

# ABC --> A (abstract class) --> B

# %%
a = A()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-7f181d8f00b8> in <cell line: 1>()
# ----> 1 a = A()
#
# TypeError: Can't instantiate abstract class A with abstract method a_test

# %%
b = B()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-bb7a6e918aa7> in <cell line: 1>()
# ----> 1 b = B()
#
# TypeError: Can't instantiate abstract class B with abstract method a_test

# %%
from abc import ABC, abstractmethod

class A(ABC):
  @abstractmethod
  def a_test(self):
    pass

class B(A):
  def a_test(self):
    print("b class a_test method")

# %%
b = B()

# %%
b.a_test()
# Out:
# b class a_test method

# %%
class A:
  @staticmethod
  def a_static():
    print("a static method")

  @classmethod
  def a_class(cls):
    print('class method')

# %%
A.a_static()
# Out:
# a static method

# %%
A.a_class()
# Out:
# class method

# %%
class A(ABC):
  @staticmethod
  def a_static():
    print("a static method")

  @classmethod
  def a_class(cls):
    print('class method')

# %%
A.a_class()
# Out:
# class method

# %%
A.a_static()
# Out:
# a static method

# %%
class A(ABC):
  @staticmethod
  def a_static():
    print("a static method")

  @classmethod
  def a_class(cls):
    print('class method')

  @abstractmethod
  def a_abstract(slef):
    pass

# %%
A.a_static()
# Out:
# a static method

# %%
A.a_class()
# Out:
# class method
